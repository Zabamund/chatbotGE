# %% [markdown]
# ## Create new Candidate entity file (single file - not three groups) with simpler synonyms and remove Pierre Maudet
#
# **Nota Bene:**
# in the Chatbot objectives the `Solution to handle spelling mistakes of candidates in chatbot users' questions` was defined as a `Should have`. Given the issues in the chatbot caused by similar synonyms, this file simplifies them to see whether we can fix the multiple entity extraction with a simpler solution.

# %%
# import libraries
import pandas as pd
import numpy as np

# %%
# import files
df = pd.read_csv('../DATA_format_JSON/candidateList_Final.csv', delimiter=";")
df.head()
# Out:
#   ELECTION.TYPE ELECTION  LEL.NUM DEPOT LEL.SIGLE  LEL.LIBELLE COURT  \
# 0                     GC              1       EAG  ENSEMBLE À GAUCHE
# 1                     GC              1       EAG  ENSEMBLE À GAUCHE
# 2                     GC              1       EAG  ENSEMBLE À GAUCHE
# 3                     GC              1       EAG  ENSEMBLE À GAUCHE
# 4                     GC              1       EAG  ENSEMBLE À GAUCHE
#
#     LEL.LIBELLE LONG CND.CIVILITE  CND.NOM CND.PRENOM CND.NOM PSEUDO  \
# 0  ENSEMBLE À GAUCHE     Monsieur   PAGANI       Rémy              -
# 1  ENSEMBLE À GAUCHE       Madame   WENGER     Saliha              -
# 2  ENSEMBLE À GAUCHE     Monsieur    ZAUGG  Christian              -
# 3  ENSEMBLE À GAUCHE       Madame   HALLER   Jocelyne              -
# 4  ENSEMBLE À GAUCHE     Monsieur  ENILINE  Alexander              -
#
#   CND.PRENOM PSEUDO
# 0                 -
# 1            Salika
# 2                 -
# 3                 -
# 4                 -

# %%
# remove dead columns
df.drop(['LEL.NUM DEPOT', 'LEL.SIGLE', 'LEL.LIBELLE COURT', 'LEL.LIBELLE LONG', 'CND.CIVILITE'], axis=1, inplace=True)
df.head()
# Out:
#   ELECTION.TYPE ELECTION  CND.NOM CND.PRENOM CND.NOM PSEUDO CND.PRENOM PSEUDO
# 0                     GC   PAGANI       Rémy              -                 -
# 1                     GC   WENGER     Saliha              -            Salika
# 2                     GC    ZAUGG  Christian              -                 -
# 3                     GC   HALLER   Jocelyne              -                 -
# 4                     GC  ENILINE  Alexander              -                 -

# %%
# to title case
df['CND.NOM'] = df['CND.NOM'].str.title()
df['CND.NOM PSEUDO'] = df['CND.NOM PSEUDO'].str.title()
df.loc[74:85]
# Out:
#    ELECTION.TYPE ELECTION            CND.NOM  CND.PRENOM  \
# 74                     GC           Leonelli       Katia
# 75                     GC       Macchiavelli       Marta
# 76                     GC            Makosso     William
# 77                     GC             Martin       David
# 78                     GC      Müller Sontag     Corinne
# 79                     GC  Nicolet-Dit-Felix      Julien
# 80                     GC               Noël    Philippe
# 81                     GC             Oriolo  Alessandra
# 82                     GC             Oztürk      Dilara
# 83                     GC           Pasquier    Isabelle
# 84                     GC              Poget    Philippe
# 85                     GC     Quijano Garcia       Maria
#
#            CND.NOM PSEUDO CND.PRENOM PSEUDO
# 74                      -                 -
# 75                      -       Marta Julia
# 76                      -                 -
# 77                      -                 -
# 78                      -                 -
# 79                      -                 -
# 80                      -                 -
# 81                      -                 -
# 82                      -                 -
# 83  Pasquier-Eichenberger                 -
# 84                      -                 -
# 85                      -        Maria José

# %%
# rename colum and add empty columns
df.rename(index=str, columns={"ELECTION.TYPE ELECTION": "entity"}, inplace=True)
df['value'] = ''
df['synonyms'] = ''
df.head()
# Out:
#   entity  CND.NOM CND.PRENOM CND.NOM PSEUDO CND.PRENOM PSEUDO value synonyms
# 0     GC   Pagani       Rémy              -                 -
# 1     GC   Wenger     Saliha              -            Salika
# 2     GC    Zaugg  Christian              -                 -
# 3     GC   Haller   Jocelyne              -                 -
# 4     GC  Eniline  Alexander              -                 -

# %%
# add value column
df['value'] = df['CND.NOM'] + " " + df['CND.PRENOM']

# %%
df.head()
# Out:
#   entity  CND.NOM CND.PRENOM CND.NOM PSEUDO CND.PRENOM PSEUDO  \
# 0     GC   Pagani       Rémy              -                 -
# 1     GC   Wenger     Saliha              -            Salika
# 2     GC    Zaugg  Christian              -                 -
# 3     GC   Haller   Jocelyne              -                 -
# 4     GC  Eniline  Alexander              -                 -
#
#                value synonyms
# 0        Pagani Rémy
# 1      Wenger Saliha
# 2    Zaugg Christian
# 3    Haller Jocelyne
# 4  Eniline Alexander

# %%
# add synonym column
df['synonyms'] = (df['CND.PRENOM'] + " " + df['CND.NOM'] + ":" 
                  + (np.where(df['CND.NOM PSEUDO'] != '-'
                              , df['CND.PRENOM'] + " " + df['CND.NOM PSEUDO'], '')) 
                  + (np.where(df['CND.PRENOM PSEUDO'] != '-'
                              , df['CND.PRENOM PSEUDO'] + " " + df['CND.NOM'], '')) 
                  + (np.where((df['CND.NOM PSEUDO'] != '-') & (df['CND.PRENOM PSEUDO'] != '-')
                              , df['CND.PRENOM PSEUDO'] + " " + df['CND.NOM PSEUDO'], ''))) 
df.iloc[55:58]
# Out:
#    entity   CND.NOM CND.PRENOM CND.NOM PSEUDO CND.PRENOM PSEUDO  \
# 55     GC  Boujemaa      Sanae              -                 -
# 56     GC   Galland    Eduardo              -                 -
# 57     GC      Jelk     Andrée     Jelk-Peila                 -
#
#               value                       synonyms
# 55   Boujemaa Sanae                Sanae Boujemaa:
# 56  Galland Eduardo               Eduardo Galland:
# 57      Jelk Andrée  Andrée Jelk:Andrée Jelk-Peila

# %%
# remove last ':' if present
df['synonyms'] = df['synonyms'].str.rstrip('\:')
df.iloc[55:58]
# Out:
#    entity   CND.NOM CND.PRENOM CND.NOM PSEUDO CND.PRENOM PSEUDO  \
# 55     GC  Boujemaa      Sanae              -                 -
# 56     GC   Galland    Eduardo              -                 -
# 57     GC      Jelk     Andrée     Jelk-Peila                 -
#
#               value                       synonyms
# 55   Boujemaa Sanae                 Sanae Boujemaa
# 56  Galland Eduardo                Eduardo Galland
# 57      Jelk Andrée  Andrée Jelk:Andrée Jelk-Peila

# %%
# remove dead columns
df.drop(['CND.NOM', 'CND.PRENOM', 'CND.NOM PSEUDO', 'CND.PRENOM PSEUDO'], axis=1, inplace=True)
df.head()
# Out:
#   entity              value                     synonyms
# 0     GC        Pagani Rémy                  Rémy Pagani
# 1     GC      Wenger Saliha  Saliha Wenger:Salika Wenger
# 2     GC    Zaugg Christian              Christian Zaugg
# 3     GC    Haller Jocelyne              Jocelyne Haller
# 4     GC  Eniline Alexander            Alexander Eniline

# %%
df.tail(1)
# Out:
#     entity           value        synonyms
# 653     CE  Amsler Susanne  Susanne Amsler

# %%
df['entity'] = 'Candidats_CE'
df.head()
# Out:
#          entity              value                     synonyms
# 0  Candidats_CE        Pagani Rémy                  Rémy Pagani
# 1  Candidats_CE      Wenger Saliha  Saliha Wenger:Salika Wenger
# 2  Candidats_CE    Zaugg Christian              Christian Zaugg
# 3  Candidats_CE    Haller Jocelyne              Jocelyne Haller
# 4  Candidats_CE  Eniline Alexander            Alexander Eniline

# %%
# drop duplicate rows
df.drop_duplicates(subset=None, keep='first', inplace=True)
len(df)
# Out:
# 627

# %%
df.head()
# Out:
#          entity              value                     synonyms
# 0  Candidats_CE        Pagani Rémy                  Rémy Pagani
# 1  Candidats_CE      Wenger Saliha  Saliha Wenger:Salika Wenger
# 2  Candidats_CE    Zaugg Christian              Christian Zaugg
# 3  Candidats_CE    Haller Jocelyne              Jocelyne Haller
# 4  Candidats_CE  Eniline Alexander            Alexander Eniline

# %%
# add colum for synonyms with no accents - copy synonmys
df['syn-no-accents'] = df['synonyms']
df.head()
# Out:
#          entity              value                     synonyms  \
# 0  Candidats_CE        Pagani Rémy                  Rémy Pagani
# 1  Candidats_CE      Wenger Saliha  Saliha Wenger:Salika Wenger
# 2  Candidats_CE    Zaugg Christian              Christian Zaugg
# 3  Candidats_CE    Haller Jocelyne              Jocelyne Haller
# 4  Candidats_CE  Eniline Alexander            Alexander Eniline
#
#                 syn-no-accents
# 0                  Rémy Pagani
# 1  Saliha Wenger:Salika Wenger
# 2              Christian Zaugg
# 3              Jocelyne Haller
# 4            Alexander Eniline

# %%
# remove accents and spec characters
df['syn-no-accents'].replace(regex=True,inplace=True,to_replace='à',value='a')
df['syn-no-accents'].replace(regex=True,inplace=True,to_replace='â',value='a')
df['syn-no-accents'].replace(regex=True,inplace=True,to_replace='ä',value='a')
df['syn-no-accents'].replace(regex=True,inplace=True,to_replace='é',value='e')
df['syn-no-accents'].replace(regex=True,inplace=True,to_replace='è',value='e')
df['syn-no-accents'].replace(regex=True,inplace=True,to_replace='ê',value='e')
df['syn-no-accents'].replace(regex=True,inplace=True,to_replace='ë',value='e')
df['syn-no-accents'].replace(regex=True,inplace=True,to_replace='ì',value='i')
df['syn-no-accents'].replace(regex=True,inplace=True,to_replace='î',value='i')
df['syn-no-accents'].replace(regex=True,inplace=True,to_replace='ï',value='i')
df['syn-no-accents'].replace(regex=True,inplace=True,to_replace='í',value='i')
df['syn-no-accents'].replace(regex=True,inplace=True,to_replace='ò',value='o')
df['syn-no-accents'].replace(regex=True,inplace=True,to_replace='ô',value='o')
df['syn-no-accents'].replace(regex=True,inplace=True,to_replace='ö',value='o')
df['syn-no-accents'].replace(regex=True,inplace=True,to_replace='ù',value='u')
df['syn-no-accents'].replace(regex=True,inplace=True,to_replace='û',value='u')
df['syn-no-accents'].replace(regex=True,inplace=True,to_replace='ü',value='u')
df['syn-no-accents'].replace(regex=True,inplace=True,to_replace='ç',value='c')
df['syn-no-accents'].replace(regex=True,inplace=True,to_replace="-",value=' ')
df['syn-no-accents'].replace(regex=True,inplace=True,to_replace="'",value=' ')

# %%
df.head()
# Out:
#          entity              value                     synonyms  \
# 0  Candidats_CE        Pagani Rémy                  Rémy Pagani
# 1  Candidats_CE      Wenger Saliha  Saliha Wenger:Salika Wenger
# 2  Candidats_CE    Zaugg Christian              Christian Zaugg
# 3  Candidats_CE    Haller Jocelyne              Jocelyne Haller
# 4  Candidats_CE  Eniline Alexander            Alexander Eniline
#
#                 syn-no-accents
# 0                  Remy Pagani
# 1  Saliha Wenger:Salika Wenger
# 2              Christian Zaugg
# 3              Jocelyne Haller
# 4            Alexander Eniline

# %%
# merge with and without accents columns
df['synonyms'] = df['synonyms'] + ":" + df['syn-no-accents']

# %%
df.head()
# Out:
#          entity              value  \
# 0  Candidats_CE        Pagani Rémy
# 1  Candidats_CE      Wenger Saliha
# 2  Candidats_CE    Zaugg Christian
# 3  Candidats_CE    Haller Jocelyne
# 4  Candidats_CE  Eniline Alexander
#
#                                             synonyms  \
# 0                            Rémy Pagani:Remy Pagani
# 1  Saliha Wenger:Salika Wenger:Saliha Wenger:Sali...
# 2                    Christian Zaugg:Christian Zaugg
# 3                    Jocelyne Haller:Jocelyne Haller
# 4                Alexander Eniline:Alexander Eniline
#
#                 syn-no-accents
# 0                  Remy Pagani
# 1  Saliha Wenger:Salika Wenger
# 2              Christian Zaugg
# 3              Jocelyne Haller
# 4            Alexander Eniline

# %%
# drop dead columns
df.drop(['syn-no-accents'], axis=1, inplace=True)
df.head()
# Out:
#          entity              value  \
# 0  Candidats_CE        Pagani Rémy
# 1  Candidats_CE      Wenger Saliha
# 2  Candidats_CE    Zaugg Christian
# 3  Candidats_CE    Haller Jocelyne
# 4  Candidats_CE  Eniline Alexander
#
#                                             synonyms
# 0                            Rémy Pagani:Remy Pagani
# 1  Saliha Wenger:Salika Wenger:Saliha Wenger:Sali...
# 2                    Christian Zaugg:Christian Zaugg
# 3                    Jocelyne Haller:Jocelyne Haller
# 4                Alexander Eniline:Alexander Eniline

# %%
# remove Pierre Maudet
df[df.value != 'Maudet Pierre']
df.iloc[195:200]
# Out:
#            entity                 value  \
# 195  Candidats_CE       Burkhard Roland
# 196  Candidats_CE  Bosshard Pierre Yves
# 197  Candidats_CE        Kurteshi Ismet
# 198  Candidats_CE         Maudet Pierre
# 199  Candidats_CE     Fontanet Nathalie
#
#                                       synonyms
# 195            Roland Burkhard:Roland Burkhard
# 196  Pierre Yves Bosshard:Pierre Yves Bosshard
# 197              Ismet Kurteshi:Ismet Kurteshi
# 198                Pierre Maudet:Pierre Maudet
# 199        Nathalie Fontanet:Nathalie Fontanet

# %%
# keep only selected candidates for 2nd round
df = df.loc[df['value'].isin(['Aymon Paul','Fontanet Nathalie'
                         ,'Cretegny Willy','Apothéloz Thierry'
                         ,'Poggia Mauro','Dal Busco Serge'
                         ,'Hodgers Antonio','Haller Jocelyne'
                         ,'Nidegger Yves','Barthassat Luc'
                         ,'Emery-Torracinta Anne'])]
df
# Out:
#            entity                  value  \
# 3    Candidats_CE        Haller Jocelyne
# 68   Candidats_CE        Hodgers Antonio
# 144  Candidats_CE  Emery-Torracinta Anne
# 145  Candidats_CE      Apothéloz Thierry
# 199  Candidats_CE      Fontanet Nathalie
# 278  Candidats_CE         Barthassat Luc
# 279  Candidats_CE        Dal Busco Serge
# 354  Candidats_CE          Nidegger Yves
# 492  Candidats_CE           Poggia Mauro
# 641  Candidats_CE             Aymon Paul
# 645  Candidats_CE         Cretegny Willy
#
#                                               synonyms
# 3                      Jocelyne Haller:Jocelyne Haller
# 68                     Antonio Hodgers:Antonio Hodgers
# 144        Anne Emery-Torracinta:Anne Emery Torracinta
# 145                Thierry Apothéloz:Thierry Apotheloz
# 199                Nathalie Fontanet:Nathalie Fontanet
# 278                      Luc Barthassat:Luc Barthassat
# 279                    Serge Dal Busco:Serge Dal Busco
# 354                        Yves Nidegger:Yves Nidegger
# 492                          Mauro Poggia:Mauro Poggia
# 641  Paul Aymon:dit Paul Sierre Aymon:Paul Aymon:di...
# 645                      Willy Cretegny:Willy Cretegny

# %%
df.reset_index(inplace=True,drop=True)
df
# Out:
#           entity                  value  \
# 0   Candidats_CE        Haller Jocelyne
# 1   Candidats_CE        Hodgers Antonio
# 2   Candidats_CE  Emery-Torracinta Anne
# 3   Candidats_CE      Apothéloz Thierry
# 4   Candidats_CE      Fontanet Nathalie
# 5   Candidats_CE         Barthassat Luc
# 6   Candidats_CE        Dal Busco Serge
# 7   Candidats_CE          Nidegger Yves
# 8   Candidats_CE           Poggia Mauro
# 9   Candidats_CE             Aymon Paul
# 10  Candidats_CE         Cretegny Willy
#
#                                              synonyms
# 0                     Jocelyne Haller:Jocelyne Haller
# 1                     Antonio Hodgers:Antonio Hodgers
# 2         Anne Emery-Torracinta:Anne Emery Torracinta
# 3                 Thierry Apothéloz:Thierry Apotheloz
# 4                 Nathalie Fontanet:Nathalie Fontanet
# 5                       Luc Barthassat:Luc Barthassat
# 6                     Serge Dal Busco:Serge Dal Busco
# 7                         Yves Nidegger:Yves Nidegger
# 8                           Mauro Poggia:Mauro Poggia
# 9   Paul Aymon:dit Paul Sierre Aymon:Paul Aymon:di...
# 10                      Willy Cretegny:Willy Cretegny

# %%
# export csv files with and without accents
df.to_csv('../electionBot_sBox/entities/candidates-Entities_v12.csv',index=False)
